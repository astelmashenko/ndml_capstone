# %% [markdown]
# # Feature Extraction
# The goal of this notebook is to cleanup, preprocess and extract features into a separate csv

# %%
import numpy as np
import pandas as pd

from IPython.display import display

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler, LabelBinarizer
from sklearn.preprocessing import Imputer
from sklearn.externals import joblib

from utils import *

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

# %%
train.head(2)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY  \
# 0               Y             0          202500.0      406597.5      24700.5
# 1               N             0          270000.0     1293502.5      35698.5
#
#    AMT_GOODS_PRICE_x NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0           351000.0   Unaccompanied          Working
# 1          1129500.0          Family    State servant
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0  Secondary / secondary special  Single / not married  House / apartment
# 1               Higher education               Married  House / apartment
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# ...

# %%
test.head(2)
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100001         Cash loans           F            N               Y
# 1      100005         Cash loans           M            N               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY  \
# 0             0          135000.0      568800.0      20560.5
# 1             0           99000.0      222768.0      17370.0
#
#    AMT_GOODS_PRICE_x NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0           450000.0   Unaccompanied          Working
# 1           180000.0   Unaccompanied          Working
#
#              NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0               Higher education            Married  House / apartment
# 1  Secondary / secondary special            Married  House / apartment
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                    0.018850      -19241          -2329            -5170.0
# ...

# %%
target = train[['TARGET']]
train.drop(columns=['TARGET'], inplace=True)

# %%
print(train.shape)
print(test.shape)
train_size = train.shape[0]
test_size = test.shape[0]
# Out:
# (307511, 174)
# (48744, 174)

# %% [markdown]
# Concatanating dataframe to do preprocessing for train and test simultaneously.

# %%
app = pd.concat([train, test])
display(app.head(2))
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0      100002         Cash loans           M            N               Y
# 1      100003         Cash loans           F            N               N
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY  \
# 0             0          202500.0      406597.5      24700.5
# 1             0          270000.0     1293502.5      35698.5
#
#    AMT_GOODS_PRICE_x NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# 0           351000.0   Unaccompanied          Working
# 1          1129500.0          Family    State servant
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0  Secondary / secondary special  Single / not married  House / apartment
# 1               Higher education               Married  House / apartment
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                    0.018801       -9461           -637            -3648.0
# ...

# %%
app.shape
# Out:
# (356255, 174)

# %% [markdown]
# ## Categorical Features

# %%
app = pd.get_dummies(app)

# %%
display(app.head(2))
# Out:
#    SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY  \
# 0      100002             0          202500.0      406597.5      24700.5
# 1      100003             0          270000.0     1293502.5      35698.5
#
#    AMT_GOODS_PRICE_x  REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0           351000.0                    0.018801       -9461           -637
# 1          1129500.0                    0.003541      -16765          -1188
#
#    DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  \
# 0            -3648.0            -2120          NaN           1
# 1            -1186.0             -291          NaN           1
#
#    FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  \
# 0               1                0                 1           1           0
# 1               1                0                 1           1           0
#
#    CNT_FAM_MEMBERS  REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# ...

# %%
print(app.dtypes.value_counts())
app.shape
# Out:
# uint8      140
# float64    118
# int64       40
# dtype: int64
# (356255, 298)

# %% [markdown]
# ## Missing Values Dropping

# %%
display(compute_missing_values(app).head(100))
# Out:
#                                   NaN %  NaN Count
# RATE_INTEREST_PRIVILEGED      98.394128     350534
# RATE_INTEREST_PRIMARY         98.394128     350534
# CC_NUNIQUE_STATUS             85.466871     304480
# AMT_PAYMENT_CURRENT           79.756074     284135
# AMT_DRAWINGS_POS_CURRENT      79.735302     284061
# AMT_DRAWINGS_ATM_CURRENT      79.735302     284061
# CNT_DRAWINGS_POS_CURRENT      79.735302     284061
# CNT_DRAWINGS_OTHER_CURRENT    79.735302     284061
# AMT_DRAWINGS_OTHER_CURRENT    79.735302     284061
# CNT_DRAWINGS_ATM_CURRENT      79.735302     284061
# AMT_PAYMENT_TOTAL_CURRENT     70.931496     252697
# CC_MONTHS_BALANCE             70.931496     252697
# AMT_BALANCE                   70.931496     252697
# AMT_CREDIT_LIMIT_ACTUAL       70.931496     252697
# AMT_DRAWINGS_CURRENT          70.931496     252697
# AMT_INST_MIN_REGULARITY       70.931496     252697
# AMT_RECEIVABLE_PRINCIPAL      70.931496     252697
# ...

# %% [markdown]
# ## Continuous Imputation

# %%
numerical = app.select_dtypes('float64').columns.tolist()
imputer = Imputer(strategy = 'median')

app[numerical] = imputer.fit_transform(app[numerical])

# %% [markdown]
# ## Continuous Features Normalization

# %%
scaler = MinMaxScaler()
app[numerical] = scaler.fit_transform(app[numerical])
display(app.head(2))
# Out:
#    SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY  \
# 0      100002             0          0.001512      0.090287     0.090032
# 1      100003             0          0.002089      0.311736     0.132924
#
#    AMT_GOODS_PRICE_x  REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0           0.077441                    0.256702       -9461           -637
# 1           0.271605                    0.045506      -16765          -1188
#
#    DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  \
# 0           0.852140            -2120     0.098901           1
# 1           0.951929             -291     0.098901           1
#
#    FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  \
# 0               1                0                 1           1           0
# 1               1                0                 1           1           0
#
#    CNT_FAM_MEMBERS  REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# ...

# %% [markdown]
# ## Save Model

# %%
data_train = app.iloc[:train_size]
data_test = app.iloc[train_size:]
print(data_train.shape)
print(data_test.shape)

# add target column back
data_train['TARGET'] = target
display(data_train.head(2))
# Out:
# (307511, 298)
# (48744, 298)
#    SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY  \
# 0      100002             0          0.001512      0.090287     0.090032
# 1      100003             0          0.002089      0.311736     0.132924
#
#    AMT_GOODS_PRICE_x  REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0           0.077441                    0.256702       -9461           -637
# 1           0.271605                    0.045506      -16765          -1188
#
#    DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  \
# 0           0.852140            -2120     0.098901           1
# 1           0.951929             -291     0.098901           1
#
#    FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  FLAG_EMAIL  \
# 0               1                0                 1           1           0
# 1               1                0                 1           1           0
#
# ...

# %%
joblib.dump(data_train, 'models/train.joblib')
# Out:
# ['models/train.joblib']

# %%
joblib.dump(data_test, 'models/test.joblib')
# Out:
# ['models/test.joblib']
